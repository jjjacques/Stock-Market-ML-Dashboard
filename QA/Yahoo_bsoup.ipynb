# %% [markdown]
# ## Financial Data Mining!

# %%
# import Dependencies
import pandas as pd
import numpy as np
from splinter import Browser
from bs4 import BeautifulSoup as bs
from datetime import datetime as dt
import requests
import json
import re
import datetime as dt
import pymysql
from sqlalchemy import create_engine
pymysql.install_as_MySQLdb()

# %%
# set up path and bsoup browser driver
executable_path = {"executable_path": "chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)

# %% [markdown]
# ## Tweeter Scraping

# %%
# Build query Url and List of Stocks ticker
twitter_url = "https://twitter.com/"
twitterNames = ["IBM", "Facebook","Google","Microsoft","Tesla","McDonalds","cognizant","Bloomberg","Apple"]
# twitterNames = ["Apple"]

# %%
# create and initialize list 
tweets_list = []
following_list = []
followers_list = []
likes_list = []
company_list = []
handle_list = []
articles1_list = []
articles2_list = []
articles3_list = []
articles4_list = []
articles5_list = []

# %%
for name in twitterNames:
    try:
    # Visit Twitter company site
        url1 = twitter_url + name
#         print(url1)
        browser.visit(url1)
        # Scrape Data into Soup
        html = browser.html
        soup = bs(html, "html.parser")
    
        # Retrieve top company name, handle and 5 current tweets articles
        articles_dic = {"Company" : [], "Handle" : [], "Articles1" : [], "Articles2" : [], "Articles3" : [], "Articles4" : [], "Articles5" : []}
        companyName = soup.find('a', class_='ProfileHeaderCard-nameLink u-textInheritColor js-nav').text
        company_list.append(companyName)
        handle_list.append("@"+companyName)
#         print(companyName)
    
        # Retrieve tweets statistics
        stats_dic = {"Tweets" : [], "Following" : [], "Followers" : [], "Likes" : []}
        stats_data = soup.find_all('span', class_='ProfileNav-value')      
        tweets_num = stats_data[0].text
        newTweets_num = tweets_num.strip()
        tweets_list.append(newTweets_num)
        followers_num = stats_data[1].text
        followers_list.append(followers_num)
        following_num = stats_data[2].text
        following_list.append(following_num)
        likes_num = stats_data[3].text
        likes_list.append(likes_num)                           
#         print(stats_dic)

        # Retrieve top company name, handle and 5 current tweets articles
        articles_list = soup.find_all('p', class_='TweetTextSize TweetTextSize--normal js-tweet-text tweet-text')
        articles1 = articles_list[0].text
        articles1_list.append(articles1)
        articles2 = articles_list[1].text
        articles2_list.append(articles2)
        articles3 = articles_list[2].text
        articles3_list.append(articles3)
        articles4 = articles_list[3].text
        articles4_list.append(articles4)
        articles5 = articles_list[4].text
        articles5_list.append(articles5)

    except IndexError as e:

        pass

# %%
# Append the retreived information into a list of dictionaries 
stats_dic = {'Tweets':tweets_list, 'Following':following_list, 'Followers':followers_list, 'Likes':likes_list}
# print(stats_dic)

articles_dic = {"Company" : company_list, "Handle" : handle_list, "Articles1" : articles1_list, "Articles2" : articles2_list, "Articles3" : articles3_list, "Articles4" : articles4_list, "Articles5" : articles5_list}
# print(articles_dic)

# %%
# print(articles_dic)

# %%
# Create Profile dataframe
stats_df = pd.DataFrame.from_dict(stats_dic, orient='index')
stats_df = stats_df.transpose()
stats_df
# Out:
#   Tweets Following Followers  Likes
# 0  12.7K      528K     6,235  7,438
# 1  12.5K     13.5M       719  1,169
# 2  98.1K     21.1M       215  2,297
# 3  15.7K     8.59M     2,567  1,651
# 4  7,326     3.81M        76  3,209
# 5   500K     3.55M     14.1K  4,828
# 6  40.6K      638K     2,784  3,132
# 7  24.3K      551K        42    792
# 8  2.89M      None     More    None

# %%
# Create Profile dataframe
articles_df = pd.DataFrame.from_dict(articles_dic, orient='index')
articles_df = articles_df.transpose()
articles_df
# Out:
#         Company         Handle  \
# 0           IBM           @IBM
# 1      Facebook      @Facebook
# 2        Google        @Google
# 3     Microsoft     @Microsoft
# 4         Tesla         @Tesla
# 5    McDonald's    @McDonald's
# 6     Cognizant     @Cognizant
# 7  Bloomberg LP  @Bloomberg LP
# 8         Apple         @Apple
#
#                                            Articles1  \
# 0  Every year, humans dump 8 million metric tons ...
# 1  https://twitter.com/engadget/status/1134489289...
# 2  IT’S HAPPENING
#
# \n\nTune into the first ever ...
# 3  Going shopping this weekend?  Thanks to tech l...
# 4  Tesla’s mission is to accelerate the world’s t...
# 5  International Currency Exchange. TODAY 2-5pm (...
# 6  Companies need to compete on software to stay ...
# 7  The @BuiltInNewYork Best Places to Work list r...
# 8                                               None
#
#                                            Articles2  \
# ...

# %%
# Combine DataFrame
stats_articles_df = pd.concat([stats_df, articles_df], axis=1, sort=True)
stats_articles_df
# Out:
#   Tweets Following Followers  Likes       Company         Handle  \
# 0  12.7K      528K     6,235  7,438           IBM           @IBM
# 1  12.5K     13.5M       719  1,169      Facebook      @Facebook
# 2  98.1K     21.1M       215  2,297        Google        @Google
# 3  15.7K     8.59M     2,567  1,651     Microsoft     @Microsoft
# 4  7,326     3.81M        76  3,209         Tesla         @Tesla
# 5   500K     3.55M     14.1K  4,828    McDonald's    @McDonald's
# 6  40.6K      638K     2,784  3,132     Cognizant     @Cognizant
# 7  24.3K      551K        42    792  Bloomberg LP  @Bloomberg LP
# 8  2.89M      None     More    None         Apple         @Apple
#
#                                            Articles1  \
# 0  Every year, humans dump 8 million metric tons ...
# 1  https://twitter.com/engadget/status/1134489289...
# 2  IT’S HAPPENING
#
# \n\nTune into the first ever ...
# 3  Going shopping this weekend?  Thanks to tech l...
# ...

# %% [markdown]
# ## Save to csv and json file

# %%
stats_articles_df.to_json (r'assets/json/stats_articles_df.json')

# %%
stats_articles_df.to_csv (r'assets/csv/stats_articles_df.csv')

# %% [markdown]
# ## Loading into Database Mysql

# %%
engine = create_engine('mysql+mysqlconnector://root:root123@127.0.0.1:3306/stock_db')

# %%
stats_articles_df.to_sql(name='tweets', con=engine, if_exists = 'append', index=False)

# %%
pd.read_sql_query('select * from tweets', con=engine).head()

# %% [markdown]
# #####

# %% [markdown]
# ## Yahoo Finance Scraping

# %%
# Build query Url and List of Stocks ticker
yahoo_url = "https://finance.yahoo.com/quote/"
# List of Stocks ticker
tickers = ["AAPL","CTSH","FB","GOOGL","IBM","MCD","MSFT","TSLA"]
# tickers = ["IBM"]

# %%
# create and initialize list 
company_name_list = []
company_desc_list = []
company_tel_list = []
company_addr_list = []
key_execs_n_list = []
key_execs_t_list = []
url_list = []

# %%
for ticker in tickers:
    try:
        # Visit Yahoo finance profile page
        url2 = yahoo_url + ticker + '/profile?p=' + ticker
    #     print(url2)
        browser.visit(url2)
        # Scrape Financial Data into Soup
        html = browser.html
        soup = bs(html, "html.parser")

        profile1 = soup.find('p', class_="D(ib) W(47.727%) Pend(40px)")
        company_addr = profile1.contents[1] + profile1.contents[5]
        company_addr_list.append(company_addr)
    #     print(company_addr)
        #type(data)
        company_name = soup.find("h3", class_="Fz(m) Mb(10px)").text
        company_name_list.append(company_name)
        company_desc = soup.find('p', class_="Mt(15px) Lh(1.6)").text
        company_desc_list.append(company_desc)
    #     print(company_desc)
        key_execs_data = soup.find('table', class_='W(100%)').find('tbody').find_all('span')
#         print(key_execs_data[0])
        key_execs_name = key_execs_data[0].contents[1]
        key_execs_title = key_execs_data[1].contents[1]
        key_execs_n_list.append(key_execs_name)
        key_execs_t_list.append(key_execs_title)
        profile = soup.find('p', class_="D(ib) W(47.727%) Pend(40px)").find_all('a')
        company_tel = profile[0].text
        company_tel_list.append(company_tel)
        url = profile[1].text
        url_list.append(url)
        
    except IndexError as e:
        pass
    except AttributeError as e:
        pass

# %%
# print(company_tel)
# print(company_tel_list)

# %%
# convert telephone number to Float
new_tel_list = []
for tel in company_tel_list:
    try:
        new_tel = tel.replace('-', '')
        new_tel_list.append(new_tel)
    except ValueError:
        pass
company_tel_list = new_tel_list
#print(company_tel_list)

# %%
# Create Profile dataframe
data_dic = {'Ticker':tickers, 'Company_Name':company_name_list, 'Description':company_desc_list, 'Telephone':company_tel_list, 'Address':company_addr_list,'Key_Execs_Name':key_execs_n_list,'Key_Execs_Title':key_execs_t_list,'Web_URL':url_list}
profile_df = pd.DataFrame.from_dict(data_dic, orient='index')
profile_df = profile_df.transpose()
profile_df
# Out:
#   Ticker                                 Company_Name  \
# 0   AAPL                                   Apple Inc.
# 1   CTSH   Cognizant Technology Solutions Corporation
# 2     FB                               Facebook, Inc.
# 3  GOOGL                                Alphabet Inc.
# 4    IBM  International Business Machines Corporation
# 5    MCD                       McDonald's Corporation
# 6   MSFT                        Microsoft Corporation
# 7   TSLA                                  Tesla, Inc.
#
#                                          Description   Telephone  \
# 0  Apple Inc. designs, manufactures, and markets ...  4089961010
# 1  Cognizant Technology Solutions Corporation, a ...  2018010233
# 2  Facebook, Inc. provides various products to co...  6505434800
# 3  Alphabet Inc. provides online advertising serv...  6502530000
# 4  International Business Machines Corporation op...  9144991900
# 5  McDonald's Corporation operates and franchises...  6306233000
# ...

# %% [markdown]
# ## Save DataFrame to csv and json file

# %%
profile_df.to_json (r'assets/json/profile_df.json')

# %%
profile_df.to_csv (r'assets/csv/profile_df.csv')

# %% [markdown]
# ## Loading into Database Mysql

# %%
engine = create_engine('mysql+mysqlconnector://root:root123@127.0.0.1:3306/stock_db')

# %%
profile_df.to_sql(name='profiles', con=engine, if_exists = 'append', index=False)

# %%
pd.read_sql_query('select * from profiles', con=engine).head()
# Out:
#   Ticker                                 Company_Name  \
# 0   AAPL                                   Apple Inc.
# 1   CTSH   Cognizant Technology Solutions Corporation
# 2     FB                               Facebook, Inc.
# 3   GOOG                                Alphabet Inc.
# 4    IBM  International Business Machines Corporation
#
#                                          Description   Telephone  \
# 0  Apple Inc. designs, manufactures, and markets ...  4089961010
# 1  Cognizant Technology Solutions Corporation, a ...  2018010233
# 2  Facebook, Inc. provides various products to co...  6505434800
# 3  Alphabet Inc. provides online advertising serv...  6502530000
# 4  International Business Machines Corporation op...  9144991900
#
#                                              Address  \
# 0              One Apple Park WayCupertino, CA 95014
# 1  Glenpointe Centre West500 Frank West Burr Boul...
# 2               1601 Willow RoadMenlo Park, CA 94025
# ...

# %% [markdown]
# ## Combine dataframes

# %%
combined_df = pd.concat([profile_df, stats_articles_df], axis=1, join='inner')
combined_df.head()
# Out:
#   Ticker                                 Company_Name  \
# 0   AAPL                                   Apple Inc.
# 1   CTSH   Cognizant Technology Solutions Corporation
# 2     FB                               Facebook, Inc.
# 3  GOOGL                                Alphabet Inc.
# 4    IBM  International Business Machines Corporation
#
#                                          Description   Telephone  \
# 0  Apple Inc. designs, manufactures, and markets ...  4089961010
# 1  Cognizant Technology Solutions Corporation, a ...  2018010233
# 2  Facebook, Inc. provides various products to co...  6505434800
# 3  Alphabet Inc. provides online advertising serv...  6502530000
# 4  International Business Machines Corporation op...  9144991900
#
#                                              Address  \
# 0              One Apple Park WayCupertino, CA 95014
# 1  Glenpointe Centre West500 Frank West Burr Boul...
# 2               1601 Willow RoadMenlo Park, CA 94025
# ...

# %%
combined_df.to_csv (r'assets/csv/companyData_df.csv')

# %% [markdown]
# ## AlphaVantage API

# %%
# Build query Url and List of Stocks ticker
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=GOOGL&apikey=Y5AE5LOO06SXQ60H
api_url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol="
api_key = "Y5AE5LOO06SXQ60H"

# List of Stocks ticker
tickers = ["AAPL","CTSH","FB","GOOGL","IBM"]
tickers2 = ["MCD","MSFT","TSLA"]

# %%
# create and initialize list 
df_list = []
stock_symbol = []
stock_daily_details = []
stock_data = []

# %%
for ticker in tickers:
    try:
        url = api_url + ticker + "&apikey=" + api_key

        stock_details = requests.get(url).json()
        stock_symbol = stock_details["Meta Data"]["2. Symbol"]
        stock_daily_details = stock_details["Time Series (Daily)"]
#         print(stock_daily_details)

        # Save json data for each API call
        with open(f'assets/data/output_api_{ticker}.json', 'w') as outfile:
            json.dump(stock_daily_details, outfile)    

    # If an error is experienced, skip the ticker
    except:
        print("ticker not found. Skipping...")
        pass

# %%
for ticker in tickers2:
    try:
        url = api_url + ticker + "&apikey=" + api_key

        stock_details = requests.get(url).json()
        stock_symbol = stock_details["Meta Data"]["2. Symbol"]
        stock_daily_details = stock_details["Time Series (Daily)"]
#         print(stock_daily_details)

        # Save json data for each API call
        with open(f'assets/data/output_api_{ticker}.json', 'w') as outfile:
            json.dump(stock_daily_details, outfile)    

    # If an error is experienced, skip the ticker
    except:
        print("ticker not found. Skipping...")
        pass

# %%
# df_CTSH_t = pd.read_json("assets/data/output_api_CTSH.json")
# df_GOOGL_t = pd.read_json("assets/data/output_api_GOOGL.json")
# df_MSFT_t = pd.read_json("assets/data/output_api_MSFT.json")
# df_TSLA_t = pd.read_json("assets/data/output_api_TSLA.json")
# df_AAPL_t = pd.read_json("assets/data/output_api_AAPL.json")
# df_IBM_t = pd.read_json("assets/data/output_api_IBM.json")
# df_FB_t = pd.read_json("assets/data/output_api_FB.json")
# df_MCD_t = pd.read_json("assets/data/output_api_MCD.json")

# %%
# # Load json data into a dataframe
# df_list = ["df_CTSH_t","df_GOOGL_t","df_MSFT_t","df_TSLA_t","df_AAPL_t","df_IBM_t","df_FB_t","df_MCD_t"]
# symbols_list = ["CTSH","GOOGL","MSFT","TSLA","AAPL","IBM","FB","MCD"]
# i = 0
# for i in range(len(df_list)):
#     df_list[i] = pd.read_json(f"assets/data/output_api_{symbols_list[i]}.json")
# #     print(df_list[i])

# %%
df_GOOGL_t.head()
# Out:
#                    2019-06-06  2019-06-05  2019-06-04  2019-06-03  2019-05-31  \
# 1. open               1046.21     1055.00     1044.49     1066.93     1105.64
# 2. high               1050.00     1056.81     1058.44     1067.00     1113.40
# 3. low                1035.51     1033.00     1036.03     1027.03     1103.35
# 4. close              1047.76     1044.64     1054.49     1038.74     1106.50
# 5. adjusted close     1047.76     1044.64     1054.49     1038.74     1106.50
#
#                    2019-05-30  2019-05-29  2019-05-28  2019-05-24  2019-05-23  \
# 1. open               1120.15     1132.70     1141.48     1152.00     1146.07
# 2. high               1126.80     1135.00     1156.49     1154.36     1150.05
# 3. low                1115.90     1111.95     1138.67     1136.71     1133.16
# 4. close              1121.41     1119.94     1139.56     1138.61     1145.34
# 5. adjusted close     1121.41     1119.94     1139.56     1138.61     1145.34
#
# ...

# %%
#Transponse data
df_CTSH = df_CTSH_t.transpose()
df_AAPL = df_AAPL_t.transpose()
df_GOOGL = df_GOOGL_t.transpose()
df_MSFT = df_MSFT_t.transpose()
df_TSLA = df_TSLA_t.transpose()
df_IBM = df_IBM_t.transpose()
df_FB = df_FB_t.transpose()
df_MCD = df_MCD_t.transpose()

# %%
df_GOOGL.head()
# Out:
#             1. open  2. high   3. low  4. close  5. adjusted close  6. volume  \
# 2019-06-06  1046.21  1050.00  1035.51   1047.76            1047.76  1414046.0
# 2019-06-05  1055.00  1056.81  1033.00   1044.64            1044.64  2261747.0
# 2019-06-04  1044.49  1058.44  1036.03   1054.49            1054.49  3025564.0
# 2019-06-03  1066.93  1067.00  1027.03   1038.74            1038.74  4844480.0
# 2019-05-31  1105.64  1113.40  1103.35   1106.50            1106.50  1579481.0
#
#             7. dividend amount  8. split coefficient
# 2019-06-06                 0.0                   1.0
# 2019-06-05                 0.0                   1.0
# 2019-06-04                 0.0                   1.0
# 2019-06-03                 0.0                   1.0
# 2019-05-31                 0.0                   1.0

# %%
# renaming a columns
df_CTSH = df_CTSH.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})
# df_CTSH.head()
df_AAPL = df_AAPL.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})
df_GOOGL = df_AAPL.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})
df_MSFT = df_AAPL.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})
df_TSLA = df_CTSH.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})
df_IBM = df_CTSH.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})
df_FB = df_CTSH.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})
df_MCD = df_CTSH.rename(columns={'1. open': 'open','2. high': 'high','3. low': 'low','4. close': 'close',
                            '5. adjusted close': 'adjusted close','6. volume': 'volume',
                            '7. dividend amount': 'dividend amount','8. split coefficient': 'split coefficient'})

# %%
# Create dataframe with only required columns
df_CTSH_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_AAPL_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_GOOGL_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_MSFT_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_TSLA_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_IBM_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_FB_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_MCD_new = df_CTSH[["open", "high", "low","close","adjusted close","volume","dividend amount"]].copy()
df_AAPL_new.head()
# Out:
#              open    high     low  close  adjusted close     volume  \
# 2019-06-06  61.94  62.150  61.745  61.90           61.90  5074617.0
# 2019-06-05  61.73  62.235  61.280  62.18           62.18  6435331.0
# 2019-06-04  61.03  61.540  58.870  61.10           61.10  7812764.0
# 2019-06-03  61.77  62.100  60.130  60.54           60.54  7308487.0
# 2019-05-31  61.73  62.330  61.730  61.93           61.93  5698594.0
#
#             dividend amount
# 2019-06-06              0.0
# 2019-06-05              0.0
# 2019-06-04              0.0
# 2019-06-03              0.0
# 2019-05-31              0.0

# %%
# change type to float
df_CTSH_new = df_CTSH_new.astype(float)
df_AAPL_new = df_AAPL_new.astype(float)
df_GOOGL_new = df_GOOGL_new.astype(float)
df_MSFT_new = df_MSFT_new.astype(float)
df_TSLA_new = df_TSLA_new.astype(float)
df_IBM_new = df_IBM_new.astype(float)
df_FB_new = df_FB_new.astype(float)
df_MCD_new = df_MCD_new.astype(float)

# %%
#  adding ticker column
df_CTSH_new ['tickers']= 'CTSH'
df_AAPL_new ['tickers']= 'APPL'
df_GOOGL_new ['tickers']= 'GOOGL'
df_MSFT_new ['tickers']= 'MSFT'
df_TSLA_new ['tickers']= 'TSLA'
df_IBM_new ['tickers']= 'IBM'
df_FB_new ['tickers']= 'FB'
df_MCD_new ['tickers']= 'MCD'
#reindexing 
df_CTSH_new = df_CTSH_new.reset_index()
df_AAPL_new = df_AAPL_new.reset_index()
df_GOOGL_new = df_GOOGL_new.reset_index()
df_MSFT_new = df_MSFT_new.reset_index()
df_TSLA_new = df_TSLA_new.reset_index()
df_IBM_new = df_IBM_new.reset_index()
df_FB_new = df_FB_new.reset_index()
df_MCD_new = df_MCD_new.reset_index()
df_CTSH_new.head()
# Out:
#        index   open    high     low  close  adjusted close     volume  \
# 0 2019-06-06  61.94  62.150  61.745  61.90           61.90  5074617.0
# 1 2019-06-05  61.73  62.235  61.280  62.18           62.18  6435331.0
# 2 2019-06-04  61.03  61.540  58.870  61.10           61.10  7812764.0
# 3 2019-06-03  61.77  62.100  60.130  60.54           60.54  7308487.0
# 4 2019-05-31  61.73  62.330  61.730  61.93           61.93  5698594.0
#
#    dividend amount tickers
# 0              0.0    CTSH
# 1              0.0    CTSH
# 2              0.0    CTSH
# 3              0.0    CTSH
# 4              0.0    CTSH

# %%
# renaming a column
df_CTSH_new = df_CTSH_new.rename(columns={'index': 'dates'})
df_AAPL_new = df_AAPL_new.rename(columns={'index': 'dates'})
df_GOOGL_new = df_GOOGL_new.rename(columns={'index': 'dates'})
df_MSFT_new = df_MSFT_new.rename(columns={'index': 'dates'})
df_TSLA_new = df_TSLA_new.rename(columns={'index': 'dates'})
df_IBM_new = df_IBM_new.rename(columns={'index': 'dates'})
df_FB_new = df_FB_new.rename(columns={'index': 'dates'})
df_MCD_new = df_MCD_new.rename(columns={'index': 'dates'})
df_MCD_new.head()
# Out:
#        dates   open    high     low  close  adjusted close     volume  \
# 0 2019-06-06  61.94  62.150  61.745  61.90           61.90  5074617.0
# 1 2019-06-05  61.73  62.235  61.280  62.18           62.18  6435331.0
# 2 2019-06-04  61.03  61.540  58.870  61.10           61.10  7812764.0
# 3 2019-06-03  61.77  62.100  60.130  60.54           60.54  7308487.0
# 4 2019-05-31  61.73  62.330  61.730  61.93           61.93  5698594.0
#
#    dividend amount tickers
# 0              0.0     MCD
# 1              0.0     MCD
# 2              0.0     MCD
# 3              0.0     MCD
# 4              0.0     MCD

# %% [markdown]
# ## Save to csv and json

# %%
df_AAPL_new.to_json (r'assets/json/df_AAPL_df.json')
df_CTSH_new.to_json (r'assets/json/df_CTSH_df.json')
df_GOOGL_new.to_json (r'assets/json/df_GOOGL_df.json')
df_MSFT_new.to_json (r'assets/json/df_MSFT_df.json')
df_TSLA_new.to_json (r'assets/json/df_TSLA_df.json')
df_IBM_new.to_json (r'assets/json/df_IBM_df.json')
df_FB_new.to_json (r'assets/json/df_FB_df.json')
df_MCD_new.to_json (r'assets/json/df_MCD_new_df.json')

# %%
df_AAPL_new.to_csv (r'assets/csv/AAPL_df.csv')
df_CTSH_new.to_csv (r'assets/csv/CTSH_df.csv')
df_GOOGL_new.to_csv (r'assets/csv/GOOGL_df.csv')
df_MSFT_new.to_csv (r'assets/csv/MSFT_df.csv')
df_TSLA_new.to_csv (r'assets/csv/TSLA_df.csv')
df_IBM_new.to_csv (r'assets/csv/IBM_df.csv')
df_FB_new.to_csv (r'assets/csv/FB_df.csv')
df_MCD_new.to_csv (r'assets/csv/MCD_df.csv')

# %% [markdown]
# ## Loading into Database Mysql

# %%
engine = create_engine('mysql+mysqlconnector://root:root123@127.0.0.1:3306/stock_db')

# %%
# PUSH eash Dataframe data into individual table
df_CTSH_new.to_sql(name='ctsh_Stock', con=engine, if_exists = 'append', index=False)
df_AAPL_new.to_sql(name='aapl_Stock', con=engine, if_exists = 'append', index=False)
df_GOOGL_new.to_sql(name='googl_Stock', con=engine, if_exists = 'append', index=False)
df_MSFT_new.to_sql(name='msft_Stock', con=engine, if_exists = 'append', index=False)
df_TSLA_new.to_sql(name='tsla_Stock', con=engine, if_exists = 'append', index=False)
df_IBM_new.to_sql(name='ibm_Stock', con=engine, if_exists = 'append', index=False)
df_FB_new.to_sql(name='fb_Stock', con=engine, if_exists = 'append', index=False)
df_MCD_new.to_sql(name='mcd_Stock', con=engine, if_exists = 'append', index=False)
# Out:
# C:\Users\james.jean-jacques\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'aapl_Stock' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# C:\Users\james.jean-jacques\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'googl_Stock' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# C:\Users\james.jean-jacques\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'msft_Stock' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# ...

# %%
# pd.read_sql_query('select * from ctsh_Stock', con=engine).head()
# pd.read_sql_query('select * from aapl_Stock', con=engine).head()
# pd.read_sql_query('select * from googl_Stock', con=engine).head()
# pd.read_sql_query('select * from msft_Stock', con=engine).head()
# pd.read_sql_query('select * from tsla_Stock', con=engine).head()
# pd.read_sql_query('select * from ibm_Stock', con=engine).head()
# pd.read_sql_query('select * from fb_Stock', con=engine).head()
pd.read_sql_query('select * from mcd_Stock', con=engine).head()
# Out:
#        dates   open   high     low  close  adjusted close     volume  \
# 0 2019-05-31  61.73  62.33  61.730  61.93           61.93  5698584.0
# 1 2019-05-30  61.94  62.90  61.750  62.36           62.36  5059753.0
# 2 2019-05-29  61.83  62.17  61.545  61.88           61.88  4540544.0
# 3 2019-05-28  62.14  62.66  61.880  62.07           62.07  6931011.0
# 4 2019-05-24  61.50  62.19  61.220  61.87           61.87  6435123.0
#
#    dividend amount tickers
# 0              0.0     MCD
# 1              0.0     MCD
# 2              0.0     MCD
# 3              0.0     MCD
# 4              0.0     MCD

# %%
df_AAPL_new.to_csv (r'assets/csv/AAPL_df.csv')
df_CTSH_new.to_csv (r'assets/csv/CTSH_df.csv')
df_GOOGL_new.to_csv (r'assets/csv/GOOGL_df.csv')
df_MSFT_new.to_csv (r'assets/csv/MSFT_df.csv')
df_TSLA_new.to_csv (r'assets/csv/TSLA_df.csv')
df_IBM_new.to_csv (r'assets/csv/IBM_df.csv')
df_FB_new.to_csv (r'assets/csv/FB_df.csv')
df_MCD_new.to_csv (r'assets/csv/MCD_df.csv')

# %%
allstocks = pd.concat([allstocks, df_MCD_new], axis=1, join='inner')

# %%
allstocks.to_csv (r'assets/csv/allstocks.csv')
